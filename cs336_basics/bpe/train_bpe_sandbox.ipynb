# %%
import os
import regex as re
from typing import BinaryIO


PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
compiled_pattern = re.compile(PAT)
input_path = "../data/TinyStoriesV2-GPT4-train.txt"
vocab_size=10000
special_tokens=["<|endoftext|>"]

# %%
with open(input_path, "rb") as f:
    raw_data = f.read(10000).decode("utf-8", errors="ignore")
    print(f"Read {len(raw_data)} characters")

stats = {}

# Step 1: Split on special tokens if provided
if special_tokens:
    # Build pattern: escape each special token and join with |
    split_pattern = "|".join(re.escape(token) for token in special_tokens)
    # Split the text, keeping only non-empty chunks
    chunks = [chunk for chunk in re.split(split_pattern, raw_data) if chunk]
else:
    chunks = [raw_data]

# Step 2: Pre-tokenize each chunk separately
for chunk in chunks:
    # iterate using finditer (memory efficient)
    for match in compiled_pattern.finditer(chunk):
        # Extract the actual string matched
        token = match.group().encode("utf-8")
        
        # Manual counting logic
        if token in stats:
            stats[token] += 1
        else:
            stats[token] = 1


print(f"Found {len(stats)} unique pre-tokens")
print("\nFirst 10 pre-tokens:")
for i, (token, count) in enumerate(list(stats.items())[:10]):
    print(f"{token!r}: {count}")
# Out:
# Read 9992 characters
# Found 523 unique pre-tokens
#
# First 10 pre-tokens:
# b'\n': 70
# b'Once': 8
# b' upon': 8
# b' a': 64
# b' time': 8
# b' there': 8
# b' was': 49
# b' little': 10
# b' boy': 6
# b' named': 10

# %%
vocab = {i: bytes([i]) for i in range(256)}
vocab[0], vocab[1], vocab[2]
# Out:
# (b'\x00', b'\x01', b'\x02')

# %%
vocab_size
# Out:
# 10000

# %%
len(vocab)
# Out:
# 256

# %%
num_merges = vocab_size - len(vocab)
num_merges
# Out:
# 9744

# %%
def get_token_frequencies(text, pattern, special_tokens=None):
    """
    Takes text and a compiled regex pattern.
    Returns a frequency table: { 'token': count, ... }
    """
    stats = {}
    
    # Step 1: Split on special tokens if provided
    if special_tokens:
        # Build pattern: escape each special token and join with |
        split_pattern = "|".join(re.escape(token) for token in special_tokens)
        # Split the text, keeping only non-empty chunks
        chunks = [chunk for chunk in re.split(split_pattern, text) if chunk]
    else:
        chunks = [text]
    
    # Step 2: Pre-tokenize each chunk separately
    for chunk in chunks:
        # iterate using finditer (memory efficient)
        for match in pattern.finditer(chunk):
            # Extract the actual string matched
            token = match.group().encode("utf-8")
            
            # Manual counting logic
            if token in stats:
                stats[token] += 1
            else:
                stats[token] = 1
            
    return stats

# %%
token_frequencies = get_token_frequencies(raw_data, compiled_pattern, special_tokens)
pairs = {}

# Loop through each token and its frequency
for token_bytes, freq in token_frequencies.items():
    # Look at consecutive pairs in this token
    # Example: ('l','o','w') → pairs are ('l','o') and ('o','w')
    for i in range(len(token_bytes) - 1):
        # Get pair at position i
        pair = (bytes([token_bytes[i]]), bytes([token_bytes[i + 1]]))
        
        # Add this pair's count (weighted by token frequency)
        if pair in pairs:
            pairs[pair] += freq
        else:
            pairs[pair] = freq

print(pairs)
# Out:
# {(b'O', b'n'): 20, (b'n', b'c'): 12, (b'c', b'e'): 15, (b' ', b'u'): 16, (b'u', b'p'): 12, (b'p', b'o'): 9, (b'o', b'n'): 50, (b' ', b'a'): 202, (b' ', b't'): 277, (b't', b'i'): 29, (b'i', b'm'): 35, (b'm', b'e'): 54, (b't', b'h'): 205, (b'h', b'e'): 269, (b'e', b'r'): 102, (b'r', b'e'): 59, (b' ', b'w'): 132, (b'w', b'a'): 71, (b'a', b's'): 71, (b' ', b'l'): 67, (b'l', b'i'): 47, (b'i', b't'): 81, (b't', b't'): 19, (b't', b'l'): 11, (b'l', b'e'): 50, (b' ', b'b'): 86, (b'b', b'o'): 25, (b'o', b'y'): 9, (b' ', b'n'): 43, (b'n', b'a'): 11, (b'a', b'm'): 36, (b'e', b'd'): 124, (b' ', b'B'): 25, (b'B', b'e'): 13, (b'e', b'n'): 74, (b'l', b'o'): 40, (b'o', b'v'): 9, (b'v', b'e'): 47, (b't', b'o'): 95, (b' ', b'e'): 26, (b'e', b'x'): 8, (b'x', b'p'): 3, (b'p', b'l'): 29, (b'o', b'r'): 42, (b'w', b'o'): 4, (b'r', b'l'): 3, (b'l', b'd'): 18, (b'a', b'r'): 53, (b'r', b'o'): 14, (b'o', b'u'): 58, (b'u', b'n'): 26, (b'n', b'd'): 142, (b' ', b'h'): 118, (b'h', b'i'): 49, (b' ', b'H'): 24, (b'H', b'e'): 23, (b' ', b's'): 144, (b's', b'a'): 42, (b'a', b'w'): 18, (b' ', b'm'): 51, (b'm', b'a'): 32, (b'a', b'n'): 138, (b'n', b'y'): 9, (b'a', b'z'): 12, (b'z', b'i'): 5, (b'i', b'n'): 99, (b'n', b'g'): 53, (b'g', b's'): 7, (b'i', b'k'): 11, (b'k', b'e'): 33, (b'b', b'e'): 21, (b'e', b'a'): 34, (b'a', b'u'): 6, (b'u', b't'): 31, (b'i', b'f'): 8, (b'f', b'u'): 12, (b'u', b'l'): 14, (b' ', b'v'): 24, (b'v', b'a'): 11, (b's', b'e'): 33, (b'e', b's'): 12, (b'h', b'a'): 49, (b'a', b't'): 45, (b'w', b'e'): 36, (b' ', b'o'): 43, (b' ', b'd'): 61, (b'd', b'i'): 15, (b'i', b's'): 53, (b's', b'p'): 12, (b'l', b'a'): 33, (b'a', b'y'): 54, (b' ', b'i'): 63, (b's', b't'): 29, (b' ', b'O'): 12, (b'n', b'e'): 50, (b'd', b'a'): 25, (b'a', b'l'): 33, (b'l', b'k'): 3, (b'k', b'i'): 5, (b'h', b'r'): 1, (b'u', b'g'): 11, (b'g', b'h'): 12, (b'w', b'h'): 9, (b' ', b'c'): 54, (b'c', b'a'): 36, (b'a', b'c'): 10, (b'c', b'r'): 5, (b'o', b's'): 8, (b's', b's'): 5, (b'r', b'y'): 28, (b'p', b'e'): 13, (b'e', b'c'): 13, (b'c', b'i'): 12, (b'i', b'a'): 5, (b' ', b'W'): 6, (b'W', b'h'): 6, (b'z', b'e'): 7, (b' ', b' '): 1, (b'a', b'i'): 39, (b'i', b'd'): 39, (b' ', b'\xe2'): 2, (b'\xe2', b'\x80'): 4, (b'\x80', b'\x9c'): 2, (b'W', b'o'): 1, (b'o', b'w'): 39, (b' ', b'r'): 27, (b'l', b'l'): 44, (b'l', b'y'): 29, (b' ', b'C'): 1, (b'C', b'a'): 1, (b' ', b'I'): 17, (b'b', b'u'): 12, (b'u', b'y'): 1, (b'?', b'\xe2'): 1, (b'\x80', b'\x9d'): 2, (b'T', b'h'): 67, (b's', b'h'): 37, (b'h', b'o'): 36, (b'o', b'p'): 2, (b'p', b'k'): 1, (b'e', b'e'): 16, (b'e', b'p'): 4, (b's', b'm'): 15, (b'm', b'i'): 13, (b'i', b'l'): 40, (b'O', b'f'): 1, (b'c', b'o'): 12, (b'u', b'r'): 11, (b'r', b's'): 10, (b' ', b'y'): 7, (b'y', b'o'): 10, (b' ', b'Y'): 3, (b'Y', b'o'): 4, (b't', b'a'): 15, (b'a', b'k'): 7, (b'o', b'm'): 66, (b' ', b'f'): 101, (b'f', b'r'): 24, (b'r', b'i'): 46, (b'i', b'e'): 37, (b'd', b's'): 14, (b'!', b'\xe2'): 1, (b'S', b'o'): 7, (b'o', b'o'): 31, (b'o', b'k'): 13, (b's', b'o'): 20, (b' ', b'p'): 60, (b'p', b'r'): 8, (b'u', b'd'): 3, (b'o', b'f'): 9, (b'e', b'm'): 16, (b' ', b'A'): 6, (b'A', b'l'): 1, (b'h', b't'): 7, (b'd', b'n'): 2, (b"'", b't'): 2, (b'e', b'l'): 28, (b'e', b'v'): 16, (b'l', b'u'): 1, (b'u', b'c'): 17, (b'c', b'k'): 19, (b'k', b'y'): 2, (b'A', b'n'): 2, (b"'", b's'): 13, (b'f', b'o'): 23, (b'a', b'b'): 6, (b'b', b'l'): 5, (b'o', b't'): 27, (b't', b'e'): 35, (b'O', b'l'): 8, (b'i', b'v'): 7, (b'w', b'i'): 33, (b'f', b'a'): 11, (b' ', b'T'): 85, (b'e', b'y'): 57, (b's', b'w'): 3, (b'o', b'g'): 13, (b'g', b'e'): 24, (b'e', b't'): 28, (b'm', b'o'): 28, (b' ', b'"'): 15, (b'h', b'u'): 12, (b'r', b'r'): 5, (b' ', b'g'): 25, (b'f', b'i'): 22, (b'n', b'n'): 5, (b'!', b'"'): 5, (b't', b'c'): 7, (b'c', b'h'): 12, (b'd', b'u'): 3, (b'H', b'i'): 6, (b'm', b'y'): 2, (b'.', b'"'): 9, (b'b', b'i'): 14, (b'i', b'g'): 24, (b'n', b'o'): 25, (b't', b'y'): 5, (b'a', b'd'): 25, (b'd', b'e'): 31, (b'a', b'p'): 11, (b'p', b'p'): 11, (b'p', b'y'): 6, (b'r', b'g'): 2, (b'g', b'o'): 14 ...

# %%
def get_pair_frequencies(vocab):
    """
    Given a vocab dict like {('l','o','w'): 5, ('l','o','w','e','r'): 2}
    Returns pair counts like {('l','o'): 7, ('o','w'): 7, ('w','e'): 2, ...}
    """
    pairs = {}
    
    # Loop through each token and its frequency
    for token_bytes, freq in vocab.items():
        # Look at consecutive pairs in this token
        # Example: ('l','o','w') → pairs are ('l','o') and ('o','w')
        for i in range(len(token_bytes) - 1):
            # Get pair at position i
            pair = (bytes([token_bytes[i]]), bytes([token_bytes[i + 1]]))
            
            # Add this pair's count (weighted by token frequency)
            if pair in pairs:
                pairs[pair] += freq
            else:
                pairs[pair] = freq
    
    return pairs
    
pair_freq = get_pair_frequencies(token_frequencies)

# %%
max_freq = max(pair_freq.values())
max_freq
# Out:
# 277

# %%
top_pairs = [pair for pair, freq in pair_freq.items() if freq == max_freq]
top_pairs
# Out:
# [(b' ', b't')]

# %%
max(top_pairs)
# Out:
# (b' ', b't')

# %%
def get_best_pair(pair_frequencies):
    """
    Returns the pair with highest frequency.
    In case of tie, returns lexicographically greater pair.
    """
    if not pair_frequencies:
        return None
    
    # Find the maximum frequency
    max_freq = max(pair_frequencies.values())
    
    # Get all pairs with that frequency
    top_pairs = [pair for pair, freq in pair_frequencies.items() if freq == max_freq]
    
    # Return the lexicographically greatest one
    # max() on tuples compares element by element
    return max(top_pairs)
    
best_pair = get_best_pair(pair_freq)

# %%
def merge_pair_in_token(token_bytes, pair_to_merge):
    """
    Merge a specific pair in a single token.
    Returns the modified token as bytes.
    """
    if len(token_bytes) < 2:
        return token_bytes
    
    new_token = []
    i = 0
    
    while i < len(token_bytes):
        # Check if we can merge at position i
        if (i < len(token_bytes) - 1 and 
            bytes([token_bytes[i]]) == pair_to_merge[0] and 
            bytes([token_bytes[i + 1]]) == pair_to_merge[1]):
            # Merge! Combine the two bytes
            new_token.append(pair_to_merge[0] + pair_to_merge[1])
            i += 2
        else:
            # Don't merge, just copy this byte
            new_token.append(bytes([token_bytes[i]]))
            i += 1
    
    # Concatenate all byte sequences
    return b''.join(new_token)

new_token = merge_pair_in_token(token_bytes, best_pair)

# %%
token_frequencies.items()
# Out:
# dict_items([(b'\n', 70), (b'Once', 8), (b' upon', 8), (b' a', 64), (b' time', 8), (b' there', 8), (b' was', 49), (b' little', 10), (b' boy', 6), (b' named', 10), (b' Ben', 12), (b'.', 188), (b' loved', 7), (b' to', 56), (b' explore', 1), (b' the', 91), (b' world', 1), (b' around', 3), (b' him', 6), (b' He', 21), (b' saw', 12), (b' many', 3), (b' amazing', 5), (b' things', 4), (b',', 97), (b' like', 8), (b' beautiful', 3), (b' vases', 1), (b' that', 12), (b' were', 12), (b' on', 11), (b' display', 1), (b' in', 16), (b' store', 3), (b' One', 5), (b' day', 18), (b' walking', 2), (b' through', 1), (b' when', 2), (b' he', 10), (b' came', 4), (b' across', 1), (b' very', 12), (b' special', 3), (b' vase', 10), (b' When', 3), (b' it', 27), (b' amazed', 2), (b'!', 10), (b'  ', 1), (b'He', 2), (b' said', 19), (b' \xe2\x80\x9c', 2), (b'Wow', 1), (b' is', 7), (b' really', 2), (b' Can', 1), (b' I', 4), (b' buy', 1), (b'?\xe2\x80\x9d', 1), (b' ', 3), (b'The', 5), (b' shopkeeper', 1), (b' smiled', 7), (b' and', 91), (b'Of', 1), (b' course', 1), (b' you', 5), (b' can', 7), (b' You', 3), (b' take', 4), (b' home', 9), (b' show', 4), (b' all', 7), (b' your', 1), (b' friends', 12), (b' how', 4), (b'!\xe2\x80\x9d', 1), (b'So', 2), (b' took', 5), (b' so', 4), (b' proud', 1), (b' of', 9), (b' called', 3), (b' his', 18), (b' over', 1), (b' showed', 3), (b' them', 13), (b' All', 1), (b' thought', 3), (b' couldn', 1), (b"'t", 2), (b' believe', 3), (b' lucky', 1), (b'And', 1), (b"'s", 13), (b' found', 9), (b' an', 4), (b' reliable', 1), (b' otter', 1), (b' Ollie', 7), (b' lived', 4), (b' river', 1), (b' with', 25), (b' family', 5), (b' They', 36), (b' play', 15), (b' swim', 1), (b' together', 6), (b'One', 7), (b' mom', 19), (b' "', 15), (b'Ollie', 1), (b' hurry', 2), (b' get', 1), (b' some', 3), (b' fish', 13), (b' for', 10), (b' dinner', 5), (b'!"', 5), (b' swam', 1), (b' fast', 3), (b' catch', 3), (b' friend', 7), (b' duck', 3), (b'Hi', 2), (b'I', 4), (b' need', 2), (b' my', 2), (b'."', 9), (b'While', 1), (b' catching', 1), (b' big', 12), (b' shiny', 4), (b' stone', 4), (b'This', 1), (b' not', 15), (b' but', 9), (b' pretty', 4), (b' looked', 3), (b' at', 6), (b' The', 16), (b' made', 6), (b' everyone', 3), (b' happy', 6), (b' they', 15), (b' forgot', 1), (b' about', 2), (b' Tim', 14), (b' went', 8), (b' park', 6), (b' tiger', 5), (b' mean', 1), (b' easy', 4), (b' played', 6), (b' had', 11), (b' lots', 2), (b' fun', 8), (b'Then', 1), (b' something', 4), (b' unexpected', 2), (b' happened', 3), (b' started', 6), (b' shake', 1), (b' scared', 3), (b' did', 4), (b' know', 1), (b' what', 2), (b' going', 1), (b' But', 4), (b' then', 3), (b' turned', 3), (b' into', 2), (b' nice', 2), (b' dog', 7), (b' surprised', 1), (b'Tim', 2), (b' now', 2), (b' too', 4), (b' At', 2), (b' end', 3), (b' new', 3), (b' friendly', 3), (b' Bob', 8), (b' pick', 3), (b' flowers', 3), (b' look', 2), (b' birds', 2), (b' decided', 3), (b' go', 6), (b' outside', 2), (b' more', 3), (b' suddenly', 1), (b' noticed', 1), (b' weird', 1), (b' ground', 2), (b' It', 12), (b' green', 2), (b' thumb', 5), (b' never', 2), (b' seen', 1), (b' one', 2), (b' before', 1), (b' curiously', 1), (b' leaned', 1), (b' better', 1), (b' told', 5), (b':', 1), (b'look', 1), (b' picked', 4), (b' up', 4), (b' this', 2), (b' What', 1), (b' do', 3), (b' we', 2), (b'?"', 2), (b'His', 1), (b' excited', 2), (b' So', 2), (b' carefully', 1), (b' carried', 1), (b' back', 4), (b' arrived', 1), (b' happily', 1), (b' His', 3), (b' dad', 2), (b' hugged', 3), (b' appreciation', 1), (b'From', 1), (b' always', 3), (b' kept', 2), (b' as', 1), (b' reminder', 1), (b' be', 3), (b' anywhere', 1), (b' small', 4), (b' house', 3), (b' girl', 2), (b' Lucy', 11), (b' color', 1), (b' orange', 6), (b' She', 5), (b' dress', 1), (b' ball', 3), (b' even', 4), (b' cat', 1), (b' met', 1), (b' This', 1), (b' other', 1), (b' spirit', 8), (b' liked', 3), (b' playing', 3), (b' her', 16), (b' having', 3), (b' much', 1), (b' Then', 1), (b' have', 2), ( ...

# %%
for i, (token_bytes, freq) in enumerate(token_frequencies.items()):
    if i >= 3:  # Stop after 3
        break
    print(f"Token {i+1}: {token_bytes!r} -> frequency: {freq}")
# Out:
# Token 1: b'\n' -> frequency: 70
# Token 2: b'Once' -> frequency: 8
# Token 3: b' upon' -> frequency: 8

# %%
token_bytes, freq = next(iter(token_frequencies.items()))
token_bytes
# Out:
# b'\n'

# %%
freq
# Out:
# 70

# %%
# merge the most frequent pair of bytes that appear together
new_token = []
i = 0

while i < len(token_bytes):
    # Check: Is token_bytes[3:5] == (b'e', b's') == pair_to_merge?
    # bytes([101]) == b'e'?  YES
    # bytes([115]) == b's'?  YES
    # Check if we can merge at position i
    if (i < len(token_bytes) - 1 and 
        bytes([token_bytes[i]]) == best_pair[0] and 
        bytes([token_bytes[i + 1]]) == best_pair[1]):
        # Merge! Combine the two bytes
        new_token.append(best_pair[0] + best_pair[1])
        print(new_token)
        i += 2
    else:
        # Don't merge, just copy this byte
        new_token.append(bytes([token_bytes[i]]))
        i += 1 # Move to next position
print(b''.join(new_token))
# new_token = [b'n', b'e', b'w', b'es']
# Out:
# b' a'

# %%
def merge_pair_in_token(token_bytes, pair_to_merge):
    """
    Merge a specific pair in a single token.
    Returns the modified token as bytes.
    """
    if len(token_bytes) < 2:
        return token_bytes
    
    new_token = []
    i = 0
    
    while i < len(token_bytes):
        # Check if we can merge at position i
        if (i < len(token_bytes) - 1 and 
            bytes([token_bytes[i]]) == pair_to_merge[0] and 
            bytes([token_bytes[i + 1]]) == pair_to_merge[1]):
            # Merge! Combine the two bytes
            new_token.append(pair_to_merge[0] + pair_to_merge[1])
            i += 2
        else:
            # Don't merge, just copy this byte
            new_token.append(bytes([token_bytes[i]]))
            i += 1
    
    # Concatenate all byte sequences
    return b''.join(new_token)

new_token = merge_pair_in_token(token_bytes, best_pair)
new_token
# Out:
# b'\n'

# %%
new_freq_table = {}

for token_bytes, freq in token_frequencies.items():
    # We'll build a new version of this token
    new_token = merge_pair_in_token(token_bytes, best_pair)
    
    if new_token in token_frequencies:
        token_frequencies[new_token] += freq
    else:
        token_frequencies[new_token] = freq

print(new_freq_table)
# Out:
# {}

# %%
def merge_pair(token_frequencies, pair_to_merge):
    """
    Takes vocab and a pair like ('s', 't')
    Returns new vocab where that pair is merged everywhere
    Example: ('n','e','w','e','s','t') → ('n','e','w','e','st') if merging ('s','t')
    """
    new_freq_table = {}
    
    for token_bytes, freq in token_frequencies.items():
        # We'll build a new version of this token
        new_token = merge_pair_in_token(token_bytes, pair_to_merge)
        
        if new_token in new_freq_table:  
            new_freq_table[new_token] += freq
        else:
            new_freq_table[new_token] = freq
    
    return new_freq_table
    
token_frequencies = merge_pair(token_frequencies, best_pair)

# %%
merged_token = best_pair[0] + best_pair[1]
merged_token
# Out:
# b' t'

# %%
vocab[next_id] = merged_token
vocab[next_id]
# Out:
# b' t'

# %%
merges = []  # Track the sequence of merges
    
for merge_num in range(3):
    # Step 1: Count all pairs
    pair_freq = get_pair_frequencies(token_frequencies)
    print(f"pair_freq: {pair_freq}")
    
    if not pair_freq:
        print(f"No more pairs to merge at step {merge_num}")
        break
    
    # Step 2: Find best pair
    best_pair = get_best_pair(pair_freq)
    print(f"best_pair: {best_pair}")
    
    # Step 3: Merge it
    token_frequencies = merge_pair(token_frequencies, best_pair)
    print(f"token_frequencies: {token_frequencies}")
    # Step 4: Record this merge
    merged_token = best_pair[0] + best_pair[1]
    vocab[next_id] = merged_token
    next_id += 1
    print(merges)
    merges.append(best_pair)
    
    if (merge_num + 1) % 100 == 0 or merge_num < 10:
        print(f"Merge {merge_num + 1}/{num_merges}: "
                f"'{best_pair[0]!r} {best_pair[1]!r} -> {merged_token!r} "
                f"(freq: {pair_freq[best_pair]})")

print(f"\nTraining complete! Final vocab size: {len(vocab)}")
print(f"merges: {merges}")
print(f"vocab: {vocab}")
# Out:
# pair_freq: {(b'O', b'n'): 40, (b'n', b'c'): 24, (b'c', b'e'): 30, (b' ', b'u'): 32, (b'u', b'p'): 24, (b'p', b'o'): 18, (b'o', b'n'): 100, (b' ', b'a'): 404, (b' ', b't'): 554, (b't', b'i'): 58, (b'i', b'm'): 70, (b'm', b'e'): 108, (b't', b'h'): 410, (b'h', b'e'): 538, (b'e', b'r'): 204, (b'r', b'e'): 118, (b' ', b'w'): 264, (b'w', b'a'): 142, (b'a', b's'): 142, (b' ', b'l'): 134, (b'l', b'i'): 94, (b'i', b't'): 162, (b't', b't'): 38, (b't', b'l'): 22, (b'l', b'e'): 100, (b' ', b'b'): 172, (b'b', b'o'): 50, (b'o', b'y'): 18, (b' ', b'n'): 86, (b'n', b'a'): 22, (b'a', b'm'): 72, (b'e', b'd'): 248, (b' ', b'B'): 50, (b'B', b'e'): 26, (b'e', b'n'): 148, (b'l', b'o'): 80, (b'o', b'v'): 18, (b'v', b'e'): 94, (b't', b'o'): 190, (b' ', b'e'): 52, (b'e', b'x'): 16, (b'x', b'p'): 6, (b'p', b'l'): 58, (b'o', b'r'): 84, (b'w', b'o'): 8, (b'r', b'l'): 6, (b'l', b'd'): 36, (b'a', b'r'): 106, (b'r', b'o'): 28, (b'o', b'u'): 116, (b'u', b'n'): 52, (b'n', b'd'): 284, (b' ', b'h'): 236, (b'h', b'i'): 98, (b' ', b'H'): 48, (b'H', b'e'): 46, (b' ', b's'): 288, (b's', b'a'): 84, (b'a', b'w'): 36, (b' ', b'm'): 102, (b'm', b'a'): 64, (b'a', b'n'): 276, (b'n', b'y'): 18, (b'a', b'z'): 24, (b'z', b'i'): 10, (b'i', b'n'): 198, (b'n', b'g'): 106, (b'g', b's'): 14, (b'i', b'k'): 22, (b'k', b'e'): 66, (b'b', b'e'): 42, (b'e', b'a'): 68, (b'a', b'u'): 12, (b'u', b't'): 62, (b'i', b'f'): 16, (b'f', b'u'): 24, (b'u', b'l'): 28, (b' ', b'v'): 48, (b'v', b'a'): 22, (b's', b'e'): 66, (b'e', b's'): 24, (b'h', b'a'): 98, (b'a', b't'): 90, (b'w', b'e'): 72, (b' ', b'o'): 86, (b' ', b'd'): 122, (b'd', b'i'): 30, (b'i', b's'): 106, (b's', b'p'): 24, (b'l', b'a'): 66, (b'a', b'y'): 108, (b' ', b'i'): 126, (b's', b't'): 58, (b' ', b'O'): 24, (b'n', b'e'): 100, (b'd', b'a'): 50, (b'a', b'l'): 66, (b'l', b'k'): 6, (b'k', b'i'): 10, (b'h', b'r'): 2, (b'u', b'g'): 22, (b'g', b'h'): 24, (b'w', b'h'): 18, (b' ', b'c'): 108, (b'c', b'a'): 72, (b'a', b'c'): 20, (b'c', b'r'): 10, (b'o', b's'): 16, (b's', b's'): 10, (b'r', b'y'): 56, (b'p', b'e'): 26, (b'e', b'c'): 26, (b'c', b'i'): 24, (b'i', b'a'): 10, (b' ', b'W'): 12, (b'W', b'h'): 12, (b'z', b'e'): 14, (b' ', b' '): 2, (b'a', b'i'): 78, (b'i', b'd'): 78, (b' ', b'\xe2'): 4, (b'\xe2', b'\x80'): 8, (b'\x80', b'\x9c'): 4, (b'W', b'o'): 2, (b'o', b'w'): 78, (b' ', b'r'): 54, (b'l', b'l'): 88, (b'l', b'y'): 58, (b' ', b'C'): 2, (b'C', b'a'): 2, (b' ', b'I'): 34, (b'b', b'u'): 24, (b'u', b'y'): 2, (b'?', b'\xe2'): 2, (b'\x80', b'\x9d'): 4, (b'T', b'h'): 134, (b's', b'h'): 74, (b'h', b'o'): 72, (b'o', b'p'): 4, (b'p', b'k'): 2, (b'e', b'e'): 32, (b'e', b'p'): 8, (b's', b'm'): 30, (b'm', b'i'): 26, (b'i', b'l'): 80, (b'O', b'f'): 2, (b'c', b'o'): 24, (b'u', b'r'): 22, (b'r', b's'): 20, (b' ', b'y'): 14, (b'y', b'o'): 20, (b' ', b'Y'): 6, (b'Y', b'o'): 8, (b't', b'a'): 30, (b'a', b'k'): 14, (b'o', b'm'): 132, (b' ', b'f'): 202, (b'f', b'r'): 48, (b'r', b'i'): 92, (b'i', b'e'): 74, (b'd', b's'): 28, (b'!', b'\xe2'): 2, (b'S', b'o'): 14, (b'o', b'o'): 62, (b'o', b'k'): 26, (b's', b'o'): 40, (b' ', b'p'): 120, (b'p', b'r'): 16, (b'u', b'd'): 6, (b'o', b'f'): 18, (b'e', b'm'): 32, (b' ', b'A'): 12, (b'A', b'l'): 2, (b'h', b't'): 14, (b'd', b'n'): 4, (b"'", b't'): 4, (b'e', b'l'): 56, (b'e', b'v'): 32, (b'l', b'u'): 2, (b'u', b'c'): 34, (b'c', b'k'): 38, (b'k', b'y'): 4, (b'A', b'n'): 4, (b"'", b's'): 26, (b'f', b'o'): 46, (b'a', b'b'): 12, (b'b', b'l'): 10, (b'o', b't'): 54, (b't', b'e'): 70, (b'O', b'l'): 16, (b'i', b'v'): 14, (b'w', b'i'): 66, (b'f', b'a'): 22, (b' ', b'T'): 170, (b'e', b'y'): 114, (b's', b'w'): 6, (b'o', b'g'): 26, (b'g', b'e'): 48, (b'e', b't'): 56, (b'm', b'o'): 56, (b' ', b'"'): 30, (b'h', b'u'): 24, (b'r', b'r'): 10, (b' ', b'g'): 50, (b'f', b'i'): 44, (b'n', b'n'): 10, (b'!', b'"'): 10, (b't', b'c'): 14, (b'c', b'h'): 24, (b'd', b'u'): 6, (b'H', b'i'): 12, (b'm', b'y'): 4, (b'.', b'"'): 18, (b'b', b'i'): 28, (b'i', b'g'): 48, (b'n', b'o'): 50, (b't', b'y'): 10, (b'a', b'd'): 50, (b'd', b'e'): 62, (b'a', b'p') ...
# best_pair: (b' ', b't')
# token_frequencies: {b'\n': 140, b'Once': 16, b' upon': 16, b' a': 128, b' time': 16, b' there': 16, b' was': 98, b' little': 20, b' boy': 12, b' named': 20, b' Ben': 24, b'.': 376, b' loved': 14, b' to': 112, b' explore': 2, b' the': 182, b' world': 2, b' around': 6, b' him': 12, b' He': 42, b' saw': 24, b' many': 6, b' amazing': 10, b' things': 8, b',': 194, b' like': 16, b' beautiful': 6, b' vases': 2, b' that': 24, b' were': 24, b' on': 22, b' display': 2, b' in': 32, b' store': 6, b' One': 10, b' day': 36, b' walking': 4, b' through': 2, b' when': 4, b' he': 20, b' came': 8, b' across': 2, b' very': 24, b' special': 6, b' vase': 20, b' When': 6, b' it': 54, b' amazed': 4, b'!': 20, b'  ': 2, b'He': 4, b' said': 38, b' \xe2\x80\x9c': 4, b'Wow': 2, b' is': 14, b' really': 4, b' Can': 2, b' I': 8, b' buy': 2, b'?\xe2\x80\x9d': 2, b' ': 6, b'The': 10, b' shopkeeper': 2, b' smiled': 14, b' and': 182, b'Of': 2, b' course': 2, b' you': 10, b' can': 14, b' You': 6, b' take': 8, b' home': 18, b' show': 8, b' all': 14, b' your': 2, b' friends': 24, b' how': 8, b'!\xe2\x80\x9d': 2, b'So': 4, b' took': 10, b' so': 8, b' proud': 2, b' of': 18, b' called': 6, b' his': 36, b' over': 2, b' showed': 6, b' them': 26, b' All': 2, b' thought': 6, b' couldn': 2, b"'t": 4, b' believe': 6, b' lucky': 2, b'And': 2, b"'s": 26, b' found': 18, b' an': 8, b' reliable': 2, b' otter': 2, b' Ollie': 14, b' lived': 8, b' river': 2, b' with': 50, b' family': 10, b' They': 72, b' play': 30, b' swim': 2, b' together': 12, b'One': 14, b' mom': 38, b' "': 30, b'Ollie': 2, b' hurry': 4, b' get': 2, b' some': 6, b' fish': 26, b' for': 20, b' dinner': 10, b'!"': 10, b' swam': 2, b' fast': 6, b' catch': 6, b' friend': 14, b' duck': 6, b'Hi': 4, b'I': 8, b' need': 4, b' my': 4, b'."': 18, b'While': 2, b' catching': 2, b' big': 24, b' shiny': 8, b' stone': 8, b'This': 2, b' not': 30, b' but': 18, b' pretty': 8, b' looked': 6, b' at': 12, b' The': 32, b' made': 12, b' everyone': 6, b' happy': 12, b' they': 30, b' forgot': 2, b' about': 4, b' Tim': 28, b' went': 16, b' park': 12, b' tiger': 10, b' mean': 2, b' easy': 8, b' played': 12, b' had': 22, b' lots': 4, b' fun': 16, b'Then': 2, b' something': 8, b' unexpected': 4, b' happened': 6, b' started': 12, b' shake': 2, b' scared': 6, b' did': 8, b' know': 2, b' what': 4, b' going': 2, b' But': 8, b' then': 6, b' turned': 6, b' into': 4, b' nice': 4, b' dog': 14, b' surprised': 2, b'Tim': 4, b' now': 4, b' too': 8, b' At': 4, b' end': 6, b' new': 6, b' friendly': 6, b' Bob': 16, b' pick': 6, b' flowers': 6, b' look': 4, b' birds': 4, b' decided': 6, b' go': 12, b' outside': 4, b' more': 6, b' suddenly': 2, b' noticed': 2, b' weird': 2, b' ground': 4, b' It': 24, b' green': 4, b' thumb': 10, b' never': 4, b' seen': 2, b' one': 4, b' before': 2, b' curiously': 2, b' leaned': 2, b' better': 2, b' told': 10, b':': 2, b'look': 2, b' picked': 8, b' up': 8, b' this': 4, b' What': 2, b' do': 6, b' we': 4, b'?"': 4, b'His': 2, b' excited': 4, b' So': 4, b' carefully': 2, b' carried': 2, b' back': 8, b' arrived': 2, b' happily': 2, b' His': 6, b' dad': 4, b' hugged': 6, b' appreciation': 2, b'From': 2, b' always': 6, b' kept': 4, b' as': 2, b' reminder': 2, b' be': 6, b' anywhere': 2, b' small': 8, b' house': 6, b' girl': 4, b' Lucy': 22, b' color': 2, b' orange': 12, b' She': 10, b' dress': 2, b' ball': 6, b' even': 8, b' cat': 2, b' met': 2, b' This': 2, b' other': 2, b' spirit': 16, b' liked': 6, b' playing': 6, b' her': 32, b' having': 6, b' much': 2, b' Then': 2, b' have': 4, b' eat': 4, b' Will': 2, b' me': 4, b' later': 2, b' nodded': 2, b'At': 2, b'Spirits': 2, b' are': 4, b' real': 4, b' imagination': 2, b' felt': 8, b' sad': 10, b' After': 2, b' she': 12, b' knew': 4, b' if': 4, b' others': 2, b' ignore': 2, b' could': 10, b' Sam': 10, b' toy': 6, b' car': 14, b' wanted': 14, b' join': 2, b' both': 2, b' battery': 4, b' inside': 10, b'Sam': 2, b' tight': 2, b' will': 8, b' fall': 2, b' out': 12, b' raced': 2, b' laugh ...
# []
# Merge 1/9744: 'b' ' b't' -> b' t' (freq: 554)
# pair_freq: {(b'O', b'n'): 40, (b'n', b'c'): 24, (b'c', b'e'): 30, (b' ', b'u'): 32, (b'u', b'p'): 24, (b'p', b'o'): 18, (b'o', b'n'): 100, (b' ', b'a'): 404, (b' ', b't'): 554, (b't', b'i'): 58, (b'i', b'm'): 70, (b'm', b'e'): 108, (b't', b'h'): 410, (b'h', b'e'): 538, (b'e', b'r'): 204, (b'r', b'e'): 118, (b' ', b'w'): 264, (b'w', b'a'): 142, (b'a', b's'): 142, (b' ', b'l'): 134, (b'l', b'i'): 94, (b'i', b't'): 162, (b't', b't'): 38, (b't', b'l'): 22, (b'l', b'e'): 100, (b' ', b'b'): 172, (b'b', b'o'): 50, (b'o', b'y'): 18, (b' ', b'n'): 86, (b'n', b'a'): 22, (b'a', b'm'): 72, (b'e', b'd'): 248, (b' ', b'B'): 50, (b'B', b'e'): 26, (b'e', b'n'): 148, (b'l', b'o'): 80, (b'o', b'v'): 18, (b'v', b'e'): 94, (b't', b'o'): 190, (b' ', b'e'): 52, (b'e', b'x'): 16, (b'x', b'p'): 6, (b'p', b'l'): 58, (b'o', b'r'): 84, (b'w', b'o'): 8, (b'r', b'l'): 6, (b'l', b'd'): 36, (b'a', b'r'): 106, (b'r', b'o'): 28, (b'o', b'u'): 116, (b'u', b'n'): 52, (b'n', b'd'): 284, (b' ', b'h'): 236, (b'h', b'i'): 98, (b' ', b'H'): 48, (b'H', b'e'): 46, (b' ', b's'): 288, (b's', b'a'): 84, (b'a', b'w'): 36, (b' ', b'm'): 102, (b'm', b'a'): 64, (b'a', b'n'): 276, (b'n', b'y'): 18, (b'a', b'z'): 24, (b'z', b'i'): 10, (b'i', b'n'): 198, (b'n', b'g'): 106, (b'g', b's'): 14, (b'i', b'k'): 22, (b'k', b'e'): 66, (b'b', b'e'): 42, (b'e', b'a'): 68, (b'a', b'u'): 12, (b'u', b't'): 62, (b'i', b'f'): 16, (b'f', b'u'): 24, (b'u', b'l'): 28, (b' ', b'v'): 48, (b'v', b'a'): 22, (b's', b'e'): 66, (b'e', b's'): 24, (b'h', b'a'): 98, (b'a', b't'): 90, (b'w', b'e'): 72, (b' ', b'o'): 86, (b' ', b'd'): 122, (b'd', b'i'): 30, (b'i', b's'): 106, (b's', b'p'): 24, (b'l', b'a'): 66, (b'a', b'y'): 108, (b' ', b'i'): 126, (b's', b't'): 58, (b' ', b'O'): 24, (b'n', b'e'): 100, (b'd', b'a'): 50, (b'a', b'l'): 66, (b'l', b'k'): 6, (b'k', b'i'): 10, (b'h', b'r'): 2, (b'u', b'g'): 22, (b'g', b'h'): 24, (b'w', b'h'): 18, (b' ', b'c'): 108, (b'c', b'a'): 72, (b'a', b'c'): 20, (b'c', b'r'): 10, (b'o', b's'): 16, (b's', b's'): 10, (b'r', b'y'): 56, (b'p', b'e'): 26, (b'e', b'c'): 26, (b'c', b'i'): 24, (b'i', b'a'): 10, (b' ', b'W'): 12, (b'W', b'h'): 12, (b'z', b'e'): 14, (b' ', b' '): 2, (b'a', b'i'): 78, (b'i', b'd'): 78, (b' ', b'\xe2'): 4, (b'\xe2', b'\x80'): 8, (b'\x80', b'\x9c'): 4, (b'W', b'o'): 2, (b'o', b'w'): 78, (b' ', b'r'): 54, (b'l', b'l'): 88, (b'l', b'y'): 58, (b' ', b'C'): 2, (b'C', b'a'): 2, (b' ', b'I'): 34, (b'b', b'u'): 24, (b'u', b'y'): 2, (b'?', b'\xe2'): 2, (b'\x80', b'\x9d'): 4, (b'T', b'h'): 134, (b's', b'h'): 74, (b'h', b'o'): 72, (b'o', b'p'): 4, (b'p', b'k'): 2, (b'e', b'e'): 32, (b'e', b'p'): 8, (b's', b'm'): 30, (b'm', b'i'): 26, (b'i', b'l'): 80, (b'O', b'f'): 2, (b'c', b'o'): 24, (b'u', b'r'): 22, (b'r', b's'): 20, (b' ', b'y'): 14, (b'y', b'o'): 20, (b' ', b'Y'): 6, (b'Y', b'o'): 8, (b't', b'a'): 30, (b'a', b'k'): 14, (b'o', b'm'): 132, (b' ', b'f'): 202, (b'f', b'r'): 48, (b'r', b'i'): 92, (b'i', b'e'): 74, (b'd', b's'): 28, (b'!', b'\xe2'): 2, (b'S', b'o'): 14, (b'o', b'o'): 62, (b'o', b'k'): 26, (b's', b'o'): 40, (b' ', b'p'): 120, (b'p', b'r'): 16, (b'u', b'd'): 6, (b'o', b'f'): 18, (b'e', b'm'): 32, (b' ', b'A'): 12, (b'A', b'l'): 2, (b'h', b't'): 14, (b'd', b'n'): 4, (b"'", b't'): 4, (b'e', b'l'): 56, (b'e', b'v'): 32, (b'l', b'u'): 2, (b'u', b'c'): 34, (b'c', b'k'): 38, (b'k', b'y'): 4, (b'A', b'n'): 4, (b"'", b's'): 26, (b'f', b'o'): 46, (b'a', b'b'): 12, (b'b', b'l'): 10, (b'o', b't'): 54, (b't', b'e'): 70, (b'O', b'l'): 16, (b'i', b'v'): 14, (b'w', b'i'): 66, (b'f', b'a'): 22, (b' ', b'T'): 170, (b'e', b'y'): 114, (b's', b'w'): 6, (b'o', b'g'): 26, (b'g', b'e'): 48, (b'e', b't'): 56, (b'm', b'o'): 56, (b' ', b'"'): 30, (b'h', b'u'): 24, (b'r', b'r'): 10, (b' ', b'g'): 50, (b'f', b'i'): 44, (b'n', b'n'): 10, (b'!', b'"'): 10, (b't', b'c'): 14, (b'c', b'h'): 24, (b'd', b'u'): 6, (b'H', b'i'): 12, (b'm', b'y'): 4, (b'.', b'"'): 18, (b'b', b'i'): 28, (b'i', b'g'): 48, (b'n', b'o'): 50, (b't', b'y'): 10, (b'a', b'd'): 50, (b'd', b'e'): 62, (b'a', b'p') ...
# best_pair: (b' ', b't')
# token_frequencies: {b'\n': 140, b'Once': 16, b' upon': 16, b' a': 128, b' time': 16, b' there': 16, b' was': 98, b' little': 20, b' boy': 12, b' named': 20, b' Ben': 24, b'.': 376, b' loved': 14, b' to': 112, b' explore': 2, b' the': 182, b' world': 2, b' around': 6, b' him': 12, b' He': 42, b' saw': 24, b' many': 6, b' amazing': 10, b' things': 8, b',': 194, b' like': 16, b' beautiful': 6, b' vases': 2, b' that': 24, b' were': 24, b' on': 22, b' display': 2, b' in': 32, b' store': 6, b' One': 10, b' day': 36, b' walking': 4, b' through': 2, b' when': 4, b' he': 20, b' came': 8, b' across': 2, b' very': 24, b' special': 6, b' vase': 20, b' When': 6, b' it': 54, b' amazed': 4, b'!': 20, b'  ': 2, b'He': 4, b' said': 38, b' \xe2\x80\x9c': 4, b'Wow': 2, b' is': 14, b' really': 4, b' Can': 2, b' I': 8, b' buy': 2, b'?\xe2\x80\x9d': 2, b' ': 6, b'The': 10, b' shopkeeper': 2, b' smiled': 14, b' and': 182, b'Of': 2, b' course': 2, b' you': 10, b' can': 14, b' You': 6, b' take': 8, b' home': 18, b' show': 8, b' all': 14, b' your': 2, b' friends': 24, b' how': 8, b'!\xe2\x80\x9d': 2, b'So': 4, b' took': 10, b' so': 8, b' proud': 2, b' of': 18, b' called': 6, b' his': 36, b' over': 2, b' showed': 6, b' them': 26, b' All': 2, b' thought': 6, b' couldn': 2, b"'t": 4, b' believe': 6, b' lucky': 2, b'And': 2, b"'s": 26, b' found': 18, b' an': 8, b' reliable': 2, b' otter': 2, b' Ollie': 14, b' lived': 8, b' river': 2, b' with': 50, b' family': 10, b' They': 72, b' play': 30, b' swim': 2, b' together': 12, b'One': 14, b' mom': 38, b' "': 30, b'Ollie': 2, b' hurry': 4, b' get': 2, b' some': 6, b' fish': 26, b' for': 20, b' dinner': 10, b'!"': 10, b' swam': 2, b' fast': 6, b' catch': 6, b' friend': 14, b' duck': 6, b'Hi': 4, b'I': 8, b' need': 4, b' my': 4, b'."': 18, b'While': 2, b' catching': 2, b' big': 24, b' shiny': 8, b' stone': 8, b'This': 2, b' not': 30, b' but': 18, b' pretty': 8, b' looked': 6, b' at': 12, b' The': 32, b' made': 12, b' everyone': 6, b' happy': 12, b' they': 30, b' forgot': 2, b' about': 4, b' Tim': 28, b' went': 16, b' park': 12, b' tiger': 10, b' mean': 2, b' easy': 8, b' played': 12, b' had': 22, b' lots': 4, b' fun': 16, b'Then': 2, b' something': 8, b' unexpected': 4, b' happened': 6, b' started': 12, b' shake': 2, b' scared': 6, b' did': 8, b' know': 2, b' what': 4, b' going': 2, b' But': 8, b' then': 6, b' turned': 6, b' into': 4, b' nice': 4, b' dog': 14, b' surprised': 2, b'Tim': 4, b' now': 4, b' too': 8, b' At': 4, b' end': 6, b' new': 6, b' friendly': 6, b' Bob': 16, b' pick': 6, b' flowers': 6, b' look': 4, b' birds': 4, b' decided': 6, b' go': 12, b' outside': 4, b' more': 6, b' suddenly': 2, b' noticed': 2, b' weird': 2, b' ground': 4, b' It': 24, b' green': 4, b' thumb': 10, b' never': 4, b' seen': 2, b' one': 4, b' before': 2, b' curiously': 2, b' leaned': 2, b' better': 2, b' told': 10, b':': 2, b'look': 2, b' picked': 8, b' up': 8, b' this': 4, b' What': 2, b' do': 6, b' we': 4, b'?"': 4, b'His': 2, b' excited': 4, b' So': 4, b' carefully': 2, b' carried': 2, b' back': 8, b' arrived': 2, b' happily': 2, b' His': 6, b' dad': 4, b' hugged': 6, b' appreciation': 2, b'From': 2, b' always': 6, b' kept': 4, b' as': 2, b' reminder': 2, b' be': 6, b' anywhere': 2, b' small': 8, b' house': 6, b' girl': 4, b' Lucy': 22, b' color': 2, b' orange': 12, b' She': 10, b' dress': 2, b' ball': 6, b' even': 8, b' cat': 2, b' met': 2, b' This': 2, b' other': 2, b' spirit': 16, b' liked': 6, b' playing': 6, b' her': 32, b' having': 6, b' much': 2, b' Then': 2, b' have': 4, b' eat': 4, b' Will': 2, b' me': 4, b' later': 2, b' nodded': 2, b'At': 2, b'Spirits': 2, b' are': 4, b' real': 4, b' imagination': 2, b' felt': 8, b' sad': 10, b' After': 2, b' she': 12, b' knew': 4, b' if': 4, b' others': 2, b' ignore': 2, b' could': 10, b' Sam': 10, b' toy': 6, b' car': 14, b' wanted': 14, b' join': 2, b' both': 2, b' battery': 4, b' inside': 10, b'Sam': 2, b' tight': 2, b' will': 8, b' fall': 2, b' out': 12, b' raced': 2, b' laugh ...
# [(b' ', b't')]
# Merge 2/9744: 'b' ' b't' -> b' t' (freq: 554)
# pair_freq: {(b'O', b'n'): 40, (b'n', b'c'): 24, (b'c', b'e'): 30, (b' ', b'u'): 32, (b'u', b'p'): 24, (b'p', b'o'): 18, (b'o', b'n'): 100, (b' ', b'a'): 404, (b' ', b't'): 554, (b't', b'i'): 58, (b'i', b'm'): 70, (b'm', b'e'): 108, (b't', b'h'): 410, (b'h', b'e'): 538, (b'e', b'r'): 204, (b'r', b'e'): 118, (b' ', b'w'): 264, (b'w', b'a'): 142, (b'a', b's'): 142, (b' ', b'l'): 134, (b'l', b'i'): 94, (b'i', b't'): 162, (b't', b't'): 38, (b't', b'l'): 22, (b'l', b'e'): 100, (b' ', b'b'): 172, (b'b', b'o'): 50, (b'o', b'y'): 18, (b' ', b'n'): 86, (b'n', b'a'): 22, (b'a', b'm'): 72, (b'e', b'd'): 248, (b' ', b'B'): 50, (b'B', b'e'): 26, (b'e', b'n'): 148, (b'l', b'o'): 80, (b'o', b'v'): 18, (b'v', b'e'): 94, (b't', b'o'): 190, (b' ', b'e'): 52, (b'e', b'x'): 16, (b'x', b'p'): 6, (b'p', b'l'): 58, (b'o', b'r'): 84, (b'w', b'o'): 8, (b'r', b'l'): 6, (b'l', b'd'): 36, (b'a', b'r'): 106, (b'r', b'o'): 28, (b'o', b'u'): 116, (b'u', b'n'): 52, (b'n', b'd'): 284, (b' ', b'h'): 236, (b'h', b'i'): 98, (b' ', b'H'): 48, (b'H', b'e'): 46, (b' ', b's'): 288, (b's', b'a'): 84, (b'a', b'w'): 36, (b' ', b'm'): 102, (b'm', b'a'): 64, (b'a', b'n'): 276, (b'n', b'y'): 18, (b'a', b'z'): 24, (b'z', b'i'): 10, (b'i', b'n'): 198, (b'n', b'g'): 106, (b'g', b's'): 14, (b'i', b'k'): 22, (b'k', b'e'): 66, (b'b', b'e'): 42, (b'e', b'a'): 68, (b'a', b'u'): 12, (b'u', b't'): 62, (b'i', b'f'): 16, (b'f', b'u'): 24, (b'u', b'l'): 28, (b' ', b'v'): 48, (b'v', b'a'): 22, (b's', b'e'): 66, (b'e', b's'): 24, (b'h', b'a'): 98, (b'a', b't'): 90, (b'w', b'e'): 72, (b' ', b'o'): 86, (b' ', b'd'): 122, (b'd', b'i'): 30, (b'i', b's'): 106, (b's', b'p'): 24, (b'l', b'a'): 66, (b'a', b'y'): 108, (b' ', b'i'): 126, (b's', b't'): 58, (b' ', b'O'): 24, (b'n', b'e'): 100, (b'd', b'a'): 50, (b'a', b'l'): 66, (b'l', b'k'): 6, (b'k', b'i'): 10, (b'h', b'r'): 2, (b'u', b'g'): 22, (b'g', b'h'): 24, (b'w', b'h'): 18, (b' ', b'c'): 108, (b'c', b'a'): 72, (b'a', b'c'): 20, (b'c', b'r'): 10, (b'o', b's'): 16, (b's', b's'): 10, (b'r', b'y'): 56, (b'p', b'e'): 26, (b'e', b'c'): 26, (b'c', b'i'): 24, (b'i', b'a'): 10, (b' ', b'W'): 12, (b'W', b'h'): 12, (b'z', b'e'): 14, (b' ', b' '): 2, (b'a', b'i'): 78, (b'i', b'd'): 78, (b' ', b'\xe2'): 4, (b'\xe2', b'\x80'): 8, (b'\x80', b'\x9c'): 4, (b'W', b'o'): 2, (b'o', b'w'): 78, (b' ', b'r'): 54, (b'l', b'l'): 88, (b'l', b'y'): 58, (b' ', b'C'): 2, (b'C', b'a'): 2, (b' ', b'I'): 34, (b'b', b'u'): 24, (b'u', b'y'): 2, (b'?', b'\xe2'): 2, (b'\x80', b'\x9d'): 4, (b'T', b'h'): 134, (b's', b'h'): 74, (b'h', b'o'): 72, (b'o', b'p'): 4, (b'p', b'k'): 2, (b'e', b'e'): 32, (b'e', b'p'): 8, (b's', b'm'): 30, (b'm', b'i'): 26, (b'i', b'l'): 80, (b'O', b'f'): 2, (b'c', b'o'): 24, (b'u', b'r'): 22, (b'r', b's'): 20, (b' ', b'y'): 14, (b'y', b'o'): 20, (b' ', b'Y'): 6, (b'Y', b'o'): 8, (b't', b'a'): 30, (b'a', b'k'): 14, (b'o', b'm'): 132, (b' ', b'f'): 202, (b'f', b'r'): 48, (b'r', b'i'): 92, (b'i', b'e'): 74, (b'd', b's'): 28, (b'!', b'\xe2'): 2, (b'S', b'o'): 14, (b'o', b'o'): 62, (b'o', b'k'): 26, (b's', b'o'): 40, (b' ', b'p'): 120, (b'p', b'r'): 16, (b'u', b'd'): 6, (b'o', b'f'): 18, (b'e', b'm'): 32, (b' ', b'A'): 12, (b'A', b'l'): 2, (b'h', b't'): 14, (b'd', b'n'): 4, (b"'", b't'): 4, (b'e', b'l'): 56, (b'e', b'v'): 32, (b'l', b'u'): 2, (b'u', b'c'): 34, (b'c', b'k'): 38, (b'k', b'y'): 4, (b'A', b'n'): 4, (b"'", b's'): 26, (b'f', b'o'): 46, (b'a', b'b'): 12, (b'b', b'l'): 10, (b'o', b't'): 54, (b't', b'e'): 70, (b'O', b'l'): 16, (b'i', b'v'): 14, (b'w', b'i'): 66, (b'f', b'a'): 22, (b' ', b'T'): 170, (b'e', b'y'): 114, (b's', b'w'): 6, (b'o', b'g'): 26, (b'g', b'e'): 48, (b'e', b't'): 56, (b'm', b'o'): 56, (b' ', b'"'): 30, (b'h', b'u'): 24, (b'r', b'r'): 10, (b' ', b'g'): 50, (b'f', b'i'): 44, (b'n', b'n'): 10, (b'!', b'"'): 10, (b't', b'c'): 14, (b'c', b'h'): 24, (b'd', b'u'): 6, (b'H', b'i'): 12, (b'm', b'y'): 4, (b'.', b'"'): 18, (b'b', b'i'): 28, (b'i', b'g'): 48, (b'n', b'o'): 50, (b't', b'y'): 10, (b'a', b'd'): 50, (b'd', b'e'): 62, (b'a', b'p') ...
# best_pair: (b' ', b't')
# token_frequencies: {b'\n': 140, b'Once': 16, b' upon': 16, b' a': 128, b' time': 16, b' there': 16, b' was': 98, b' little': 20, b' boy': 12, b' named': 20, b' Ben': 24, b'.': 376, b' loved': 14, b' to': 112, b' explore': 2, b' the': 182, b' world': 2, b' around': 6, b' him': 12, b' He': 42, b' saw': 24, b' many': 6, b' amazing': 10, b' things': 8, b',': 194, b' like': 16, b' beautiful': 6, b' vases': 2, b' that': 24, b' were': 24, b' on': 22, b' display': 2, b' in': 32, b' store': 6, b' One': 10, b' day': 36, b' walking': 4, b' through': 2, b' when': 4, b' he': 20, b' came': 8, b' across': 2, b' very': 24, b' special': 6, b' vase': 20, b' When': 6, b' it': 54, b' amazed': 4, b'!': 20, b'  ': 2, b'He': 4, b' said': 38, b' \xe2\x80\x9c': 4, b'Wow': 2, b' is': 14, b' really': 4, b' Can': 2, b' I': 8, b' buy': 2, b'?\xe2\x80\x9d': 2, b' ': 6, b'The': 10, b' shopkeeper': 2, b' smiled': 14, b' and': 182, b'Of': 2, b' course': 2, b' you': 10, b' can': 14, b' You': 6, b' take': 8, b' home': 18, b' show': 8, b' all': 14, b' your': 2, b' friends': 24, b' how': 8, b'!\xe2\x80\x9d': 2, b'So': 4, b' took': 10, b' so': 8, b' proud': 2, b' of': 18, b' called': 6, b' his': 36, b' over': 2, b' showed': 6, b' them': 26, b' All': 2, b' thought': 6, b' couldn': 2, b"'t": 4, b' believe': 6, b' lucky': 2, b'And': 2, b"'s": 26, b' found': 18, b' an': 8, b' reliable': 2, b' otter': 2, b' Ollie': 14, b' lived': 8, b' river': 2, b' with': 50, b' family': 10, b' They': 72, b' play': 30, b' swim': 2, b' together': 12, b'One': 14, b' mom': 38, b' "': 30, b'Ollie': 2, b' hurry': 4, b' get': 2, b' some': 6, b' fish': 26, b' for': 20, b' dinner': 10, b'!"': 10, b' swam': 2, b' fast': 6, b' catch': 6, b' friend': 14, b' duck': 6, b'Hi': 4, b'I': 8, b' need': 4, b' my': 4, b'."': 18, b'While': 2, b' catching': 2, b' big': 24, b' shiny': 8, b' stone': 8, b'This': 2, b' not': 30, b' but': 18, b' pretty': 8, b' looked': 6, b' at': 12, b' The': 32, b' made': 12, b' everyone': 6, b' happy': 12, b' they': 30, b' forgot': 2, b' about': 4, b' Tim': 28, b' went': 16, b' park': 12, b' tiger': 10, b' mean': 2, b' easy': 8, b' played': 12, b' had': 22, b' lots': 4, b' fun': 16, b'Then': 2, b' something': 8, b' unexpected': 4, b' happened': 6, b' started': 12, b' shake': 2, b' scared': 6, b' did': 8, b' know': 2, b' what': 4, b' going': 2, b' But': 8, b' then': 6, b' turned': 6, b' into': 4, b' nice': 4, b' dog': 14, b' surprised': 2, b'Tim': 4, b' now': 4, b' too': 8, b' At': 4, b' end': 6, b' new': 6, b' friendly': 6, b' Bob': 16, b' pick': 6, b' flowers': 6, b' look': 4, b' birds': 4, b' decided': 6, b' go': 12, b' outside': 4, b' more': 6, b' suddenly': 2, b' noticed': 2, b' weird': 2, b' ground': 4, b' It': 24, b' green': 4, b' thumb': 10, b' never': 4, b' seen': 2, b' one': 4, b' before': 2, b' curiously': 2, b' leaned': 2, b' better': 2, b' told': 10, b':': 2, b'look': 2, b' picked': 8, b' up': 8, b' this': 4, b' What': 2, b' do': 6, b' we': 4, b'?"': 4, b'His': 2, b' excited': 4, b' So': 4, b' carefully': 2, b' carried': 2, b' back': 8, b' arrived': 2, b' happily': 2, b' His': 6, b' dad': 4, b' hugged': 6, b' appreciation': 2, b'From': 2, b' always': 6, b' kept': 4, b' as': 2, b' reminder': 2, b' be': 6, b' anywhere': 2, b' small': 8, b' house': 6, b' girl': 4, b' Lucy': 22, b' color': 2, b' orange': 12, b' She': 10, b' dress': 2, b' ball': 6, b' even': 8, b' cat': 2, b' met': 2, b' This': 2, b' other': 2, b' spirit': 16, b' liked': 6, b' playing': 6, b' her': 32, b' having': 6, b' much': 2, b' Then': 2, b' have': 4, b' eat': 4, b' Will': 2, b' me': 4, b' later': 2, b' nodded': 2, b'At': 2, b'Spirits': 2, b' are': 4, b' real': 4, b' imagination': 2, b' felt': 8, b' sad': 10, b' After': 2, b' she': 12, b' knew': 4, b' if': 4, b' others': 2, b' ignore': 2, b' could': 10, b' Sam': 10, b' toy': 6, b' car': 14, b' wanted': 14, b' join': 2, b' both': 2, b' battery': 4, b' inside': 10, b'Sam': 2, b' tight': 2, b' will': 8, b' fall': 2, b' out': 12, b' raced': 2, b' laugh ...
# [(b' ', b't'), (b' ', b't')]
# Merge 3/9744: 'b' ' b't' -> b' t' (freq: 554)
#
# Training complete! Final vocab size: 3703
# merges: [(b' ', b't'), (b' ', b't'), (b' ', b't')]
# vocab: {0: b'\x00', 1: b'\x01', 2: b'\x02', 3: b'\x03', 4: b'\x04', 5: b'\x05', 6: b'\x06', 7: b'\x07', 8: b'\x08', 9: b'\t', 10: b'\n', 11: b'\x0b', 12: b'\x0c', 13: b'\r', 14: b'\x0e', 15: b'\x0f', 16: b'\x10', 17: b'\x11', 18: b'\x12', 19: b'\x13', 20: b'\x14', 21: b'\x15', 22: b'\x16', 23: b'\x17', 24: b'\x18', 25: b'\x19', 26: b'\x1a', 27: b'\x1b', 28: b'\x1c', 29: b'\x1d', 30: b'\x1e', 31: b'\x1f', 32: b' ', 33: b'!', 34: b'"', 35: b'#', 36: b'$', 37: b'%', 38: b'&', 39: b"'", 40: b'(', 41: b')', 42: b'*', 43: b'+', 44: b',', 45: b'-', 46: b'.', 47: b'/', 48: b'0', 49: b'1', 50: b'2', 51: b'3', 52: b'4', 53: b'5', 54: b'6', 55: b'7', 56: b'8', 57: b'9', 58: b':', 59: b';', 60: b'<', 61: b'=', 62: b'>', 63: b'?', 64: b'@', 65: b'A', 66: b'B', 67: b'C', 68: b'D', 69: b'E', 70: b'F', 71: b'G', 72: b'H', 73: b'I', 74: b'J', 75: b'K', 76: b'L', 77: b'M', 78: b'N', 79: b'O', 80: b'P', 81: b'Q', 82: b'R', 83: b'S', 84: b'T', 85: b'U', 86: b'V', 87: b'W', 88: b'X', 89: b'Y', 90: b'Z', 91: b'[', 92: b'\\', 93: b']', 94: b'^', 95: b'_', 96: b'`', 97: b'a', 98: b'b', 99: b'c', 100: b'd', 101: b'e', 102: b'f', 103: b'g', 104: b'h', 105: b'i', 106: b'j', 107: b'k', 108: b'l', 109: b'm', 110: b'n', 111: b'o', 112: b'p', 113: b'q', 114: b'r', 115: b's', 116: b't', 117: b'u', 118: b'v', 119: b'w', 120: b'x', 121: b'y', 122: b'z', 123: b'{', 124: b'|', 125: b'}', 126: b'~', 127: b'\x7f', 128: b'\x80', 129: b'\x81', 130: b'\x82', 131: b'\x83', 132: b'\x84', 133: b'\x85', 134: b'\x86', 135: b'\x87', 136: b'\x88', 137: b'\x89', 138: b'\x8a', 139: b'\x8b', 140: b'\x8c', 141: b'\x8d', 142: b'\x8e', 143: b'\x8f', 144: b'\x90', 145: b'\x91', 146: b'\x92', 147: b'\x93', 148: b'\x94', 149: b'\x95', 150: b'\x96', 151: b'\x97', 152: b'\x98', 153: b'\x99', 154: b'\x9a', 155: b'\x9b', 156: b'\x9c', 157: b'\x9d', 158: b'\x9e', 159: b'\x9f', 160: b'\xa0', 161: b'\xa1', 162: b'\xa2', 163: b'\xa3', 164: b'\xa4', 165: b'\xa5', 166: b'\xa6', 167: b'\xa7', 168: b'\xa8', 169: b'\xa9', 170: b'\xaa', 171: b'\xab', 172: b'\xac', 173: b'\xad', 174: b'\xae', 175: b'\xaf', 176: b'\xb0', 177: b'\xb1', 178: b'\xb2', 179: b'\xb3', 180: b'\xb4', 181: b'\xb5', 182: b'\xb6', 183: b'\xb7', 184: b'\xb8', 185: b'\xb9', 186: b'\xba', 187: b'\xbb', 188: b'\xbc', 189: b'\xbd', 190: b'\xbe', 191: b'\xbf', 192: b'\xc0', 193: b'\xc1', 194: b'\xc2', 195: b'\xc3', 196: b'\xc4', 197: b'\xc5', 198: b'\xc6', 199: b'\xc7', 200: b'\xc8', 201: b'\xc9', 202: b'\xca', 203: b'\xcb', 204: b'\xcc', 205: b'\xcd', 206: b'\xce', 207: b'\xcf', 208: b'\xd0', 209: b'\xd1', 210: b'\xd2', 211: b'\xd3', 212: b'\xd4', 213: b'\xd5', 214: b'\xd6', 215: b'\xd7', 216: b'\xd8', 217: b'\xd9', 218: b'\xda', 219: b'\xdb', 220: b'\xdc', 221: b'\xdd', 222: b'\xde', 223: b'\xdf', 224: b'\xe0', 225: b'\xe1', 226: b'\xe2', 227: b'\xe3', 228: b'\xe4', 229: b'\xe5', 230: b'\xe6', 231: b'\xe7', 232: b'\xe8', 233: b'\xe9', 234: b'\xea', 235: b'\xeb', 236: b'\xec', 237: b'\xed', 238: b'\xee', 239: b'\xef', 240: b'\xf0', 241: b'\xf1', 242: b'\xf2', 243: b'\xf3', 244: b'\xf4', 245: b'\xf5', 246: b'\xf6', 247: b'\xf7', 248: b'\xf8', 249: b'\xf9', 250: b'\xfa', 251: b'\xfb', 252: b'\xfc', 253: b'\xfd', 254: b'\xfe', 255: b'\xff', 256: b' t', 257: b' t', 258: b' t', 259: b' t', 260: b' t', 261: b' t', 262: b' t', 263: b' t', 264: b' t', 265: b' t', 266: b' t', 267: b' t', 268: b' t', 269: b' t', 270: b' t', 271: b' t', 272: b' t', 273: b' t', 274: b' t', 275: b' t', 276: b' t', 277: b' t', 278: b' t', 279: b' t', 280: b' t', 281: b' t', 282: b' t', 283: b' t', 284: b' t', 285: b' t', 286: b' t', 287: b' t', 288: b' t', 289: b' t', 290: b' t', 291: b' t', 292: b' t', 293: b' t', 294: b' t', 295: b' t', 296: b' t', 297: b' t', 298: b' t', 299: b' t', 300: b' t', 301: b' t', 302: b' t', 303: b' t', 304: b' t', 305: b' t', 306: b' t', 307: b' t', 308: b' t', 309: b' t', 310: b' t', 311: b' t', 312: b' t', 313: b' t', 314: b' t', 315: b' t', 316: b' t', 317: b' t', 318: b' t', 319: b' t', 320: b' t', 321: b' t', 322: b' t', 323: ...
